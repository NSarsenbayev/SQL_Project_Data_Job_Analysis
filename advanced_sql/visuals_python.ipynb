# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv(r"D:\Database developer\SQL_Project_Data_Job_Analysis\CSV files\visualization_1.csv")

df.columns
# Out:
# Index(['job_title', 'salary_year_avg'], dtype='object')

# %%
# Sort by salary just to be sure
df_sorted = df.sort_values(by="salary_year_avg", ascending=False)
df_sorted
# Out:
#                                          job_title  salary_year_avg
# 0                                     Data Analyst         650000.0
# 1                            Director of Analytics         336500.0
# 2                Associate Director- Data Insights         255829.5
# 3                          Data Analyst, Marketing         232423.0
# 4                     Data Analyst (Hybrid/Remote)         217000.0
# 5                  Principal Data Analyst (Remote)         205000.0
# 6                  Director, Data Analyst - HYBRID         189309.0
# 7  Principal Data Analyst, AV Performance Analysis         189000.0
# 8                           Principal Data Analyst         186000.0
# 9                                 ERM Data Analyst         184000.0

# %%
df_demanded_skills = pd.read_csv(r"D:\Database developer\SQL_Project_Data_Job_Analysis\CSV files\visualization_3.csv")
df_demanded_skills
# Out:
#      skills  demand_count
# 0       sql         92628
# 1     excel         67031
# 2    python         57326
# 3   tableau         46554
# 4  power bi         39468

# %%
sns.barplot(data=df_demanded_skills, x="skills", y="demand_count")
sns.despine()
plt.title("Top In-demand Skills in 2023 for Data Analyst Jobs in the US")
plt.xlabel("")
plt.ylabel("Demand Count")
plt.show()

# %%
df_high_paying_skills = pd.read_csv(r"D:\Database developer\SQL_Project_Data_Job_Analysis\CSV files\visualization_4.csv")

# %%
sns.barplot(data=df_high_paying_skills, x="salary_avg", y="skills", hue="skills", palette="dark:b")
sns.set_theme(style="ticks")
sns.despine()
plt.title("High Paying Skills")
plt.xlabel("Average Salary $USD")
plt.ylabel("")
plt.show()

# %%
df_optimal_skills = pd.read_csv(r"D:\Database developer\SQL_Project_Data_Job_Analysis\CSV files\visualization_5.csv")
df_optimal_skills
# Out:
#    skill_id      skills  demand_count  salary_avg
# 0         0         sql           398       97237
# 1       181       excel           256       87288
# 2         1      python           236      101397
# 3       182     tableau           230       99288
# 4         5           r           148      100499
# 5       183    power bi           110       97431
# 6         7         sas            63       98902
# 7       186         sas            63       98902
# 8       196  powerpoint            58       88701
# 9       185      looker            49      103795

# %%
sns.barplot(data=df_optimal_skills, x="salary_avg", y="skills")

sns.despine()
plt.title("Optimal Skills")
plt.xlabel("Average Salary $USD")
plt.ylabel("")
plt.show()
